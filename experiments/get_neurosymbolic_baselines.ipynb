# %%
# %load_ext autoreload
# %autoreload 2

# %%
import asyncio
import os
import pandas as pd
import numpy as np

from hfppl.modeling import Model
from hfppl.distributions import LMContext, TokenCategorical
from hfppl.llms import CachedCausalLM
from hfppl.inference import smc_standard

from battleship.board import Board
from battleship.scoring import compute_score
from battleship.models import QuestionGenerationModel

# %%
# Load HF_AUTH_TOKEN from .hf_auth_token
HF_AUTH_TOKEN = os.environ["HF_AUTH_TOKEN"]

# %%
# Initialize the HuggingFace model
lm = CachedCausalLM.from_pretrained("codellama/CodeLlama-13b-hf", auth_token=HF_AUTH_TOKEN)
# Out:
# /home/ubuntu/anaconda3/envs/python311/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:671: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /home/ubuntu/anaconda3/envs/python311/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:472: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# /home/ubuntu/anaconda3/envs/python311/lib/python3.11/site-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(

# %% [markdown]
# # Prompting utils

# %%
df = pd.read_csv("../battleship/prompts/examples.csv")

def format_example(user_input: str, response: str = None):
    return f"User: {user_input}\n" f"Assistant:{' ' + response if response else ''}"

def make_question_prompt(df, board=None, instructions=None):
    prompt = ""
    if instructions != None:
        prompt += f"Instructions:\n{instructions}\n"
    if board != None:
        prompt += "Board:\n" + board.to_textual_description() + "\n"
    prompt += "Questions:\n" + "\n".join(df.question) + "\n"
    return prompt

def make_question_to_code_prompt(df):
    prompt = "\n".join([format_example(q, r) for q, r in zip(df.question, df.code)]) + "\n"
    return prompt

# %%
instructions = "User input will be a series of sentences representing a board from Battleship, the board game, that you should aim to win. Tiles in the board can either be 'Water' tiles, 'Blue Ship' tiles, 'Red Ship' tiles, and 'Purple Ship' tiles (there are only these three battleships). Some tiles may also be 'Hidden' tiles, meaning they could be any of the others but have not been revealed yet. The user will denote coordinates as follows: columns are numbered from 1 onwards, where column 1 is the leftmost column, and rows are given a letter from A onwards where row A is the topmost row (so the cell at the second row and second column is B2). Your role is to ask the most informative possible question from the context given: strictly output the question only, and make sure the questions are relevant to the context: 'Which cells should I target to sink the battleships with the least number of moves?' is not a relevant question because it is the general goal of Battleship. Questions also need to be answerable with yes or no, no other questions will be considered in scope."

# %% [markdown]
# # Single board evaluation

# %%
board = Board.from_trial_id(5)
board.to_textual_description()
# Out:
# '1-A is a hidden tile.\n1-B is a hidden tile.\n1-C is a purple ship tile.\n1-D is a hidden tile.\n1-E is a hidden tile.\n1-F is a hidden tile.\n2-A is a hidden tile.\n2-B is a hidden tile.\n2-C is a water tile.\n2-D is a hidden tile.\n2-E is a hidden tile.\n2-F is a hidden tile.\n3-A is a hidden tile.\n3-B is a hidden tile.\n3-C is a hidden tile.\n3-D is a water tile.\n3-E is a hidden tile.\n3-F is a hidden tile.\n4-A is a hidden tile.\n4-B is a hidden tile.\n4-C is a hidden tile.\n4-D is a blue ship tile.\n4-E is a hidden tile.\n4-F is a hidden tile.\n5-A is a hidden tile.\n5-B is a hidden tile.\n5-C is a hidden tile.\n5-D is a blue ship tile.\n5-E is a hidden tile.\n5-F is a hidden tile.\n6-A is a hidden tile.\n6-B is a hidden tile.\n6-C is a hidden tile.\n6-D is a blue ship tile.\n6-E is a hidden tile.\n6-F is a hidden tile.'

# %%
# Create a model instance

model = QuestionGenerationModel(
    lm=lm,
    board=board,
    question_prompt=make_question_prompt(df),
    translation_prompt=make_question_to_code_prompt(df),
)


model_board = QuestionGenerationModel(
    lm=lm,
    board=board,
    question_prompt=make_question_prompt(df,board=board),
    translation_prompt=make_question_to_code_prompt(df),
)

model_instructions = QuestionGenerationModel(
    lm=lm,
    board=board,
    question_prompt=make_question_prompt(df,instructions=instructions),
    translation_prompt=make_question_to_code_prompt(df),
)

model_combined = QuestionGenerationModel(
    lm=lm,
    board=board,
    question_prompt=make_question_prompt(df,board=board,instructions=instructions),
    translation_prompt=make_question_to_code_prompt(df),
)

# %%
particle_num = 3

particles = await smc_standard(model, n_particles=particle_num)
print("Done with standard model...")
particles_b = await smc_standard(model_board, n_particles=particle_num)
print("Done with board model...")
particles_i = await smc_standard(model_instructions, n_particles=particle_num)
print("Done with instruction model...")
particles_c = await smc_standard(model_combined, n_particles=particle_num)
print("Done with combined model...")

# %%
df_results = []
for i, p in enumerate(particles):
    df_p = pd.DataFrame(p.get_final_results())
    df_p["particle"] = i
    df_results.append(df_p)
df_results = pd.concat(df_results).reset_index(drop=True)
df_results

# %%
df_results.sort_values("score", ascending=False).head(10)

# %%
df_results.query("type == 'final'")

# %%
for p in particles:
    print(f"Question: {str(p.context)}")
    print(f"|- Program: {p.result['translation']}")
    print(f"|- EIG: {compute_score(board=board, program=p.result['translation'])}")
    print(f"|- Particle weight: {p.weight:.4f}")
    print()

# %% [markdown]
# # Multiple board evaluation

# %%
TRIAL_IDS = range(1, 19)
N_PARTICLES = 5

for model_type in ["REGULAR","COMBINED"]:
    for trial_id in TRIAL_IDS:
        df_results = []
        print("-" * 80)
        print(f"Trial {trial_id}")
        print("-" * 80)
        board = Board.from_trial_id(trial_id)
        if model_type == "REGULAR":
            model = QuestionGenerationModel(
                lm=lm,
                board=board,
                question_prompt=make_question_prompt(df, board=None, instructions=None),
                translation_prompt=make_question_to_code_prompt(df),
            )
        elif model_type == "COMBINED":
            model = QuestionGenerationModel(
                lm=lm,
                board=board,
                question_prompt=make_question_prompt(df, board=board, instructions=instructions),
                translation_prompt=make_question_to_code_prompt(df),
            )
        particles = await smc_standard(model, n_particles=N_PARTICLES)
        df_trial = []
        for i, p in enumerate(particles):
            df_p = pd.DataFrame(p.get_final_results())
            df_p["particle"] = i
            df_p["model_type"] = model_type
            df_trial.append(df_p)
        df_trial = pd.concat(df_trial).reset_index(drop=True)
        df_trial["trial_id"] = trial_id
        df_results.append(df_trial)
        df_results = pd.concat(df_results).reset_index(drop=True)
        if not os.path.isfile('hfppl_results.csv'):
            df_results.to_csv('hfppl_results.csv', header='column_names', index=False)
        else:
            df_results.to_csv("hfppl_results.csv", mode="a", index=False)
# Out:
# --------------------------------------------------------------------------------
# Trial 1
# --------------------------------------------------------------------------------
# Partial question: Is
# |- EIG mean: 0.7563
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Is the red ship touching the blue ship?
#     |- Translation: (touch Red Blue)
#     |- Score: 0.7563
#   |- Completion: Is the blue ship touching the red ship?
#     |- Translation: (touch Blue Red)
#     |- Score: 0.7563
#   |- Completion: Is the red ship touching the blue ship?
#     |- Translation: (touch Red Blue)
#     |- Score: 0.7563
#
# Partial question: How
# |- EIG mean: 0.4536
# |- EIG max: 1.3608
# |- Particle weight: 1.3608
#   |- Completion: How many ships are there?
#     |- Translation: (++ (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many blocks is the blue ship?
#     |- Translation: (size Blue)
#     |- Score: 1.3608
#   |- Completion: How many coordinates contain a ship?
#     |- Translation: (++ (map (lambda x0 (length (coloredTiles x0))) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: How
# |- EIG mean: 0.7532
# |- EIG max: 2.2595
# |- Particle weight: 2.2595
#   |- Completion: How many ships are in this puzzle?
#     |- Translation: (++ (map (lambda x0 (not (== (size x0) 0))) (set AllColors)))
#     |- Score: -0.0000
#   |- Completion: How many tiles are there on the board?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.2595
#   |- Completion: How many blocks are in the top row?
#     |- Translation: (++ (map (lambda x0 (== (topleft x0) 1-A)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Are
# |- EIG mean: 0.0000
# |- EIG max: -0.0000
# |- Particle weight: 0.0000
#   |- Completion: Are there any ships touching from 4 squares?
#     |- Translation: (any (map (lambda x0 (== (touch x0) 4)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are there any ships in the second half of the grid?
#     |- Translation: (any (map (lambda x0 (> (topleft x0) 5-A)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are there any squares occupied by more than one ship?
#     |- Translation: (any (map (lambda x0 (> (size x0) 1)) (set AllColors)))
#     |- Score: -0.0000
#
# Partial question: Use
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use the values of the coordinates to answer the questions.
#     |- Translation: (let ((x1 (topleft (coloredTiles Red))) (x2 (bottomright (coloredTiles Red)))) (let ((x
#     |- Score: 0.0000
#   |- Completion: Use Cases:
#     |- Translation: (map (lambda x0 (list (coloredTiles x0) (size x0) (orient x0))) (set AllColors))
#     |- Score: 0.0000
#   |- Completion: Use A1 notation
#     |- Translation: (map (lambda x0 (cons (car x0) (cdr x0))) (coloredTiles Red))
#     |- Score: 0.0000
#
# Partial question: Is the
# |- EIG mean: 0.2521
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Is the red ship touching the blue ship?
#     |- Translation: (touch Red Blue)
#     |- Score: 0.7563
#   |- Completion: Is the green ship touching the purple ship?
#     |- Translation: (touch Green Purple)
#     |- Score: 0.0000
#   |- Completion: Is the red ship touching the green ship?
#     |- Translation: (touch Red Green)
#     |- Score: 0.0000
#
# Partial question: How many
# |- EIG mean: 1.2068
# |- EIG max: 2.2595
# |- Particle weight: 2.2595
#   |- Completion: How many tiles are in the blue ship?
#     |- Translation: (size Blue)
#     |- Score: 1.3608
#   |- Completion: How many ships are there?
#     |- Translation: (++ (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many total squares are free?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.2595
#
# Partial question: How many
# |- EIG mean: 1.5862
# |- EIG max: 2.2595
# |- Particle weight: 2.2595
#   |- Completion: How many squares have at least one ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.2595
#   |- Completion: How many squares are occupied by the blue ship?
#     |- Translation: (size Blue)
#     |- Score: 1.3608
#   |- Completion: How many squares are touching the blue ship?
#     |- Translation: (++ (map (lambda x0 (touch x0 Blue)) (set AllColors)))
#     |- Score: 1.1385
#
# Partial question: Are the
# |- EIG mean: 0.2521
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the ships stacked in order by length?
#     |- Translation: (all (lambda x0 (== (size x0) (size (nth (sub1 (length (set AllColors))) (set AllCol
#     |- Score: 0.0000
#   |- Completion: Are the ships touching each other?
#     |- Translation: (any (map (lambda x0 (touch x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are the red and blue ships touching?
#     |- Translation: (touch Red Blue)
#     |- Score: 0.7563
#
# Partial question: Use comments
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to clarify your answer and write a program to print all the questions and their answers, without using a single if or for statement.
#     |- Translation: (map (lambda x0 (list (question x0) (answer x0))) (set AllColors))
#     |- Score: 0.0000
#   |- Completion: Use comments to identify and describe the ships!
#     |- Translation: (comment (coloredTiles Red) (coloredTiles Blue) (coloredTiles Purple))
#     |- Score: 0.0000
#   |- Completion: Use comments to ask questions about the board layout:
#     |- Translation: (comment "What is the color of the ship at 1A?")
#     |- Score: 0.0000
#
# Partial question: How many t
# |- EIG mean: 1.3608
# |- EIG max: 1.3608
# |- Particle weight: 1.3608
#   |- Completion: How many tiles does the blue ship have?
#     |- Translation: (size Blue)
#     |- Score: 1.3608
#   |- Completion: How many tiles are occupied by the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.3608
#   |- Completion: How many tiles does the blue ship have?
#     |- Translation: (size Blue)
#     |- Score: 1.3608
#
# Partial question: How many rows
# |- EIG mean: 0.7532
# |- EIG max: 2.2595
# |- Particle weight: 2.2595
#   |- Completion: How many rows of the grid are occupied by ships?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.2595
#   |- Completion: How many rows are there?
#     |- Translation: (++ (map (lambda x0 (topleft x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many rows contain 3 or more ships?
#     |- Translation: (++ (map (lambda x0 (>= (size x0) 3)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Are the pur
# |- EIG mean: 0.5840
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the purple ship and the blue ship touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple ship and the blue ship touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple ship and the blue ship touching each other?
#     |- Translation: (and (touch Purple Blue) (not (== (color 1-A) Water)))
#     |- Score: 0.2395
#
# Partial question: Is the blue
# |- EIG mean: 0.5833
# |- EIG max: 0.9935
# |- Particle weight: 0.9935
#   |- Completion: Is the blue ship touching the purple ship?
#     |- Translation: (touch Blue Purple)
#     |- Score: 0.7563
#   |- Completion: Is the blue ship horizontal?
#     |- Translation: (== (orient Blue) H)
#     |- Score: 0.9935
#   |- Completion: Is the blue ship to the right of the red ship?
#     |- Translation: (> (x (topleft (coloredTiles Blue))) (x (topleft (coloredTiles Red))))
#     |- Score: 0.0000
#
# Partial question: Use comments to
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to describe the answers to the above questions.
#     |- Translation: (comment (size Red) (== (size Purple) 4) (orient Purple) (== (orient Purple) V) (color
#     |- Score: 0.0000
#   |- Completion: Use comments to help the user understand the game.
#     |- Translation: (comment "The game is played on a 10x10 grid. Each square is either water or occupied by a ship. The ships are of
#     |- Score: 0.0000
#   |- Completion: Use comments to clarify questions or create extras.
#     |- Translation: (comment "This is a comment")
#     |- Score: 0.0000
#
# Partial question: Is the blue ship
# |- EIG mean: 0.7563
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Is the blue ship touching the red ship?
#     |- Translation: (touch Blue Red)
#     |- Score: 0.7563
#   |- Completion: Is the blue ship touching the purple ship?
#     |- Translation: (touch Blue Purple)
#     |- Score: 0.7563
#   |- Completion: Is the blue ship touching the red ship?
#     |- Translation: (touch Blue Red)
#     |- Score: 0.7563
#
# Partial question: Are the purple
# |- EIG mean: 0.7563
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the purple and red ships touching?
#     |- Translation: (touch Purple Red)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple ship and red ship touching each other?
#     |- Translation: (touch Purple Red)
#     |- Score: 0.7563
#
# Partial question: How many tiles
# |- EIG mean: 0.9072
# |- EIG max: 1.3608
# |- Particle weight: 1.3608
#   |- Completion: How many tiles are in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.3608
#   |- Completion: How many tiles are touching the ocean?
#     |- Translation: (++ (map (lambda x0 (touch x0 Water)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many tiles are in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.3608
#
# Partial question: Use comments to provide
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to provide answers to any of the above questions.
#     |- Translation: (comment (size Red) (== (size Purple) 4) (orient Purple) (== (orient Purple) V) (color
#     |- Score: 0.0000
#   |- Completion: Use comments to provide the answer and explanation
#     |- Translation: (comment "The red ship has 3 tiles, the purple ship has 4 tiles, and the blue ship has 2 tiles.
#     |- Score: 0.0000
#   |- Completion: Use comments to provide additional detail that will help others answer your question.
#     |- Translation: (comment "This is a comment")
#     |- Score: 0.0000
#
# Partial question: How many rows does
# |- EIG mean: 1.2191
# |- EIG max: 1.8286
# |- Particle weight: 1.8286
#   |- Completion: How many rows does the blue ship take up?
#     |- Translation: (++ (map (lambda x0 (== (orient x0) H)) (set AllColors)))
#     |- Score: 1.8286
#   |- Completion: How many rows does the ship on 5C take up?
#     |- Translation: (++ (map (lambda x0 (size x0)) (filter (lambda x0 (== (coloredTiles x0) (colored
#     |- Score: 0.0000
#   |- Completion: How many rows does the red ship occupy?
#     |- Translation: (++ (map (lambda x0 (== (orient x0) V)) (set AllColors)))
#     |- Score: 1.8286
#
# Partial question: Is the blue ship horizontal
# |- EIG mean: 0.9935
# |- EIG max: 0.9935
# |- Particle weight: 0.9935
#   |- Completion: Is the blue ship horizontal?
#     |- Translation: (== (orient Blue) H)
#     |- Score: 0.9935
#   |- Completion: Is the blue ship horizontal or vertical?
#     |- Translation: (== (orient Blue) H)
#     |- Score: 0.9935
#   |- Completion: Is the blue ship horizontal or vertical?
#     |- Translation: (== (orient Blue) H)
#     |- Score: 0.9935
#
# Partial question: Are the purple and
# |- EIG mean: 0.2521
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships in a straight line?
#     |- Translation: (straightline Purple Blue)
#     |- Score: 0.0000
#   |- Completion: Are the purple and the green ship touching?
#     |- Translation: (touch Purple Green)
#     |- Score: 0.0000
#
# Partial question: How many rows does the
# |- EIG mean: 0.7532
# |- EIG max: 2.2595
# |- Particle weight: 2.2595
#   |- Completion: How many rows does the purple ship take up?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.2595
#   |- Completion: How many rows does the red ship occupy?
#     |- Translation: (++ (map (lambda x0 (size x0)) (filter (lambda x0 (== (color x0) Red)) (set AllCol
#     |- Score: 0.0000
#   |- Completion: How many rows does the red ship occupy?
#     |- Translation: (++ (map (lambda x0 (size x0)) (filter (lambda x0 (== (color x0) Red)) (set AllCol
#     |- Score: 0.0000
#
# Partial question: How many tiles are
# |- EIG mean: 0.9072
# |- EIG max: 1.3608
# |- Particle weight: 1.3608
#   |- Completion: How many tiles are there on the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.3608
#   |- Completion: How many tiles are in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.3608
#   |- Completion: How many tiles are in the water?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) Water)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Use comments to provide your
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answer.
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answer
#     |- Translation: (comment "The red ship is 4 tiles long, and the purple ship is 3 tiles long.")
#     |- Score: 0.0000
#
# Partial question: Is the blue ship horizontal?
# |- EIG mean: 0.9935
# |- EIG max: 0.9935
# |- Particle weight: 0.9935
#   |- Completion: Is the blue ship horizontal?
#     |- Translation: (== (orient Blue) H)
#     |- Score: 0.9935
#   |- Completion: Is the blue ship horizontal?
#     |- Translation: (== (orient Blue) H)
#     |- Score: 0.9935
#   |- Completion: Is the blue ship horizontal?
#     |- Translation: (== (orient Blue) H)
#     |- Score: 0.9935
#
# Partial question: Use comments to provide your answers
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to provide your answers.
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to these questions.
#     |- Translation: (comment "How many blocks is the red ship?")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to these questions
#     |- Translation: (comment "How many blocks is the red ship?")
#     |- Score: 0.0000
#
# Partial question: Are the purple and blue
# |- EIG mean: 0.8330
# |- EIG max: 0.9866
# |- Particle weight: 0.9866
#   |- Completion: Are the purple and blue ships the same length?
#     |- Translation: (== (size Purple) (size Blue))
#     |- Score: 0.9866
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#
# Partial question: How many tiles are there
# |- EIG mean: 1.6603
# |- EIG max: 2.2595
# |- Particle weight: 2.2595
#   |- Completion: How many tiles are there in the grid?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.2595
#   |- Completion: How many tiles are there in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.3608
#   |- Completion: How many tiles are there in the blue ship?
#     |- Translation: (size Blue)
#     |- Score: 1.3608
#
# Partial question: How many rows does the region
# |- EIG mean: 0.7532
# |- EIG max: 2.2595
# |- Particle weight: 2.2595
#   |- Completion: How many rows does the region contain?
#     |- Translation: (++ (map (lambda x0 (bottomright x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many rows does the region cover?
#     |- Translation: (++ (map (lambda x0 (bottomright x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many rows does the region have?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.2595
#
# Partial question: Are the purple and blue ships
# |- EIG mean: 0.7563
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#
# Partial question: How many rows does the region have
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many rows does the region have?
#     |- Translation: (++ (map (lambda x0 (bottomright x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many rows does the region have?
#     |- Translation: (++ (map (lambda x0 (bottomright x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many rows does the region have?
#     |- Translation: (++ (map (lambda x0 (bottomright x0)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Use comments to provide your answers to
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to provide your answers to the questions.
#     |- Translation: (comment "How many total squares are occupied by ships?")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "How many blocks is the red ship?")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions.
#     |- Translation: (comment "Use comments to provide your answers to the questions.")
#     |- Score: 0.0000
#
# Partial question: How many tiles are there around
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many tiles are there around the ship at 3E?
#     |- Translation: (++ (map (lambda x0 (distance x0 3-E)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the ship at 1F?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (neighbors 1-F))))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the first block of the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (neighbors (topleft (coloredTiles Red))))))
#     |- Score: 0.0000
#
# Partial question: Are the purple and blue ships touch
# |- EIG mean: 0.7563
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#
# Partial question: How many rows does the region have?
# |- EIG mean: 0.7532
# |- EIG max: 2.2595
# |- Particle weight: 2.2595
#   |- Completion: How many rows does the region have?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.2595
#   |- Completion: How many rows does the region have?
#     |- Translation: (++ (map (lambda x0 (bottomright x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many rows does the region have?
#     |- Translation: (++ (map (lambda x0 (bottomright x0)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Use comments to provide your answers to the
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to provide your answers to the above questions.
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "How many blocks is the red ship?")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above:
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#
# Partial question: How many tiles are there around the
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many tiles are there around the green ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (neighbors Green))))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the ship at 1B?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (neighbors 1-B))))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the purple ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (neighbors Purple))))
#     |- Score: 0.0000
#
# Partial question: Are the purple and blue ships touching
# |- EIG mean: 0.7563
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#
# Partial question: How many tiles are there around the red
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many tiles are there around the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (touched Red))))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (touched Red))))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (touched Red))))
#     |- Score: 0.0000
#
# Partial question: Use comments to provide your answers to the questions
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment (size Red) (== (size Purple) 4) (orient Purple) (== (orient Purple) V) (color
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions, and then click submit to check your answers.
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#
# Partial question: How many tiles are there around the red ship
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many tiles are there around the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (touched Red))))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (touched Red))))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (touched Red))))
#     |- Score: 0.0000
#
# Partial question: Use comments to provide your answers to the questions above
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "The red ship has 2 tiles.")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "How many blocks is the red ship?")
#     |- Score: 0.0000
#
# Partial question: Are the purple and blue ships touching each
# |- EIG mean: 0.7563
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the purple and blue ships touching each other?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching each other?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching each other?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#
# Partial question: Are the purple and blue ships touching each other
# |- EIG mean: 0.7563
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the purple and blue ships touching each other?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching each other?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching each other?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#
# Partial question: Use comments to provide your answers to the questions above.
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "The red ship has 3 tiles.")
#     |- Score: 0.0000
#   |- Completion: Use comments to provide your answers to the questions above.
#     |- Translation: (comment "How many blocks is the red ship?")
#     |- Score: 0.0000
#
# Partial question: How many tiles are there around the red ship?
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many tiles are there around the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (touches Red))))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (touchedby Red))))
#     |- Score: 0.0000
#   |- Completion: How many tiles are there around the red ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (touched Red))))
#     |- Score: 0.0000
#
# Partial question: Are the purple and blue ships touching each other?
# |- EIG mean: 0.7563
# |- EIG max: 0.7563
# |- Particle weight: 0.7563
#   |- Completion: Are the purple and blue ships touching each other?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching each other?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#   |- Completion: Are the purple and blue ships touching each other?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.7563
#
# --------------------------------------------------------------------------------
# Trial 2
# --------------------------------------------------------------------------------
# Partial question:
#
# |- EIG mean: 0.9388
# |- EIG max: 1.4082
# |- Particle weight: 1.4082
#   |- Completion: ## Answer Key
#     |- Translation: (define AllColors (set Red Purple Blue))
#     |- Score: 0.0000
#   |- Completion: Answer:
#     |- Translation: (size Red)
#     |- Score: 1.4082
#   |- Completion: ### Answer:
#     |- Translation: (size Red)
#     |- Score: 1.4082
#
# Partial question: How
# |- EIG mean: 2.0612
# |- EIG max: 2.3877
# |- Particle weight: 2.3877
#   |- Completion: How big is the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4082
#   |- Completion: How many squares are occupied by a ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.3877
#   |- Completion: How many squares are occupied by ships?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.3877
#
# Partial question: How
# |- EIG mean: 1.2653
# |- EIG max: 2.3877
# |- Particle weight: 2.3877
#   |- Completion: How long is the longest ship?
#     |- Translation: (max (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many blocks are in the blue ship?
#     |- Translation: (size Blue)
#     |- Score: 1.4082
#   |- Completion: How many squares are occupied by ships?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.3877
#
# Partial question: This
# |- EIG mean: 0.2919
# |- EIG max: 0.8757
# |- Particle weight: 0.8757
#   |- Completion: This game is a classic version of Battleship in which no ships may touch edges.
#     |- Translation: (== (size Red) 5)
#     |- Score: -0.0000
#   |- Completion: This is a sample puzzle.
#     |- Translation: (== (size Red) 3)
#     |- Score: 0.8757
#   |- Completion: This puzzle has 10 questions, each of which is determined by the given diagram.
#     |- Translation: (== (size Red) 10)
#     |- Score: -0.0000
#
# Partial question: There
# |- EIG mean: 0.0192
# |- EIG max: 0.0575
# |- Particle weight: 0.0575
#   |- Completion: There are exactly 12 squares that are occupied by a ship.
#     |- Translation: (== (++ (map (lambda x0 (size x0)) (set AllColors))) 12)
#     |- Score: 0.0575
#   |- Completion: There are 100 squares on the board, 50 of which are occupied by ships.
#     |- Translation: (== (++ (map (lambda x0 (size x0)) (set AllColors))) 50)
#     |- Score: -0.0000
#   |- Completion: There are 5 ships in the diagram:
#     |- Translation: (== (length (set AllColors)) 5)
#     |- Score: 0.0000
#
# Partial question: How many
# |- EIG mean: 0.9388
# |- EIG max: 1.4082
# |- Particle weight: 1.4082
#   |- Completion: How many tiles are in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4082
#   |- Completion: How many ships are in the BLUE box?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) (coloredTiles Blue))) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many squares are occupied by the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4082
#
# Partial question: This is
# |- EIG mean: 0.7899
# |- EIG max: 0.8757
# |- Particle weight: 0.8757
#   |- Completion: This is a highly complex game which we will try to explain.
#     |- Translation: (== (size Red) 3)
#     |- Score: 0.8757
#   |- Completion: This is a question from the 2018 CCS010/UOFT011/CSI011 exam.
#     |- Translation: (== (size Red) 3)
#     |- Score: 0.8757
#   |- Completion: This is an extension of the famous "Battleship" game.
#     |- Translation: (== (size Red) 4)
#     |- Score: 0.6181
#
# Partial question: There are
# |- EIG mean: 0.8677
# |- EIG max: 0.9924
# |- Particle weight: 0.9924
#   |- Completion: There are two ships: blue and red.
#     |- Translation: (== (size Blue) 2)
#     |- Score: 0.9924
#   |- Completion: There are two ships, four tiles each.
#     |- Translation: (== (size Red) 4)
#     |- Score: 0.6181
#   |- Completion: There are 2 ships in this diagram, and the coordinates for their squares are represented as (x,y), where x is the horizontal coordinate and y is the vertical
#     |- Translation: (== (size Red) 2)
#     |- Score: 0.9924
#
# Partial question: How many
# |- EIG mean: 0.7959
# |- EIG max: 2.3877
# |- Particle weight: 2.3877
#   |- Completion: How many tiles does the largest ship have?
#     |- Translation: (max (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many ships are at 1B, 4B, 8B, or 11B?
#     |- Translation: (++ (map (lambda x0 (== (topleft x0) 1-B)) (set AllColors)) (map (lambda x
#     |- Score: 0.0000
#   |- Completion: How many tiles are in the grid?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.3877
#
# Partial question: How many different
# |- EIG mean: 0.7959
# |- EIG max: 2.3877
# |- Particle weight: 2.3877
#   |- Completion: How many different positions are there for the</s>
#     |- Translation: (load "exercise_1_1.lsp")
#     |- Score: 0.0000
#   |- Completion: How many different shapes of ships are there?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.3877
#   |- Completion: How many different ships are in play?
#     |- Translation: (++ (set AllColors))
#     |- Score: 0.0000
#
# Partial question: How many rows
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many rows of tiles are occupied by at least one ship?
#     |- Translation: (++ (map (lambda x0 (bottomright x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many rows are occupied by ships?
#     |- Translation: (++ (map (lambda x0 (height x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many rows are there?
#     |- Translation: (++ (map (lambda x0 (bottomright x0)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: This is a
# |- EIG mean: 1.8177
# |- EIG max: 4.5773
# |- Particle weight: 4.5773
#   |- Completion: This is a game.
#     |- Translation: (== (class Game) Game)
#     |- Score: 0.0000
#   |- Completion: This is a simple problem that requires some basic rules and logic.
#     |- Translation: (== (size Red) 3)
#     |- Score: 0.8757
#   |- Completion: This is a puzzle game, where you have to find the coordinate of the first block of the red ship.
#     |- Translation: (topleft (coloredTiles Red))
#     |- Score: 4.5773
#
# Partial question: There are in
# |- EIG mean: 0.5060
# |- EIG max: 0.9924
# |- Particle weight: 0.9924
#   |- Completion: There are in total 10 ships over the ocean.
#     |- Translation: (== (++ (map (lambda x0 (size x0)) (set AllColors))) 10)
#     |- Score: 0.5256
#   |- Completion: There are in total 4 ships.
#     |- Translation: (== (++ (map (lambda x0 (size x0)) (set AllColors))) 4)
#     |- Score: -0.0000
#   |- Completion: There are in total 20 blocks of which 2 are blue, 2 are red, 1 is purple and 12 are neutral.
#     |- Translation: (== (size Blue) 2)
#     |- Score: 0.9924
#
# Partial question: This is a post
# |- EIG mean: 0.7195
# |- EIG max: 0.8757
# |- Particle weight: -0.5727
#   |- Completion: This is a post-mortem for a game of Battleship that I played with a friend.
#     |- Translation: (== (size Red) 4)
#     |- Score: 0.6181
#   |- Completion: This is a post about the Battleship game.
#     |- Translation: (== (color 1-A) Water)
#     |- Score: 0.6647
#   |- Completion: This is a post with an answer!
#     |- Translation: (== (size Red) 3)
#     |- Score: 0.8757
#
# Partial question: How many different colors
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.7412
#   |- Completion: How many different colors of ships are there?
#     |- Translation: (++ (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many different colors of squares are occupied by ships?
#     |- Translation: (++ (map (lambda x0 (color x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many different colors of ships are there?
#     |- Translation: (++ (set AllColors))
#     |- Score: 0.0000
#
# Partial question: This is a
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: -1.4485
#   |- Completion: This is a 4x4 board with 12 blocks.
#     |- Translation: (== (size Board) 4)
#     |- Score: 0.0000
#   |- Completion: This is a 5x5 board, and the ships are in the form of a 3x3 grid
#     |- Translation: (== (size Board) 5)
#     |- Score: 0.0000
#   |- Completion: This is a 3x3 board
#     |- Translation: (== (size Board) 3)
#     |- Score: 0.0000
#
# Partial question: How many different boats
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.7412
#   |- Completion: How many different boats (different sizes) are there?
#     |- Translation: (++ (set (map (lambda x0 (size x0)) (set AllColors))))
#     |- Score: 0.0000
#   |- Completion: How many different boats are there in total?
#     |- Translation: (++ (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many different boats appear on the board?
#     |- Translation: (++ (set AllColors))
#     |- Score: 0.0000
#
# Partial question: How many different boats are
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 1.7172
#   |- Completion: How many different boats are there?
#     |- Translation: (length (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many different boats are there?
#     |- Translation: (length (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many different boats are there?
#     |- Translation: (length (set AllColors))
#     |- Score: 0.0000
#
# Partial question: How many different boats are there
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 1.7172
#   |- Completion: How many different boats are there?
#     |- Translation: (length (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many different boats are there?
#     |- Translation: (length (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many different boats are there?
#     |- Translation: (length (set AllColors))
#     |- Score: 0.0000
#
# Partial question: How many different boats are there?
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 1.7172
#   |- Completion: How many different boats are there?
#     |- Translation: (length (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many different boats are there?
#     |- Translation: (length (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many different boats are there?
#     |- Translation: (length (set AllColors))
#     |- Score: 0.0000
#
# --------------------------------------------------------------------------------
# Trial 3
# --------------------------------------------------------------------------------
# Partial question: How
# |- EIG mean: 1.4394
# |- EIG max: 1.4394
# |- Particle weight: 1.4394
#   |- Completion: How many tiles are in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4394
#   |- Completion: How many ships are in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4394
#   |- Completion: How many tiles are in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4394
#
# Partial question: Is
# |- EIG mean: 0.2200
# |- EIG max: 0.6601
# |- Particle weight: 0.6601
#   |- Completion: Is the</s>
#     |- Translation: Can you tell me how to get to the airport?
#     |- Score: 0.0000
#   |- Completion: Is the purple ship touching the water?
#     |- Translation: (not (touch Purple Water))
#     |- Score: 0.0000
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.6601
#
# Partial question: How
# |- EIG mean: 1.1547
# |- EIG max: 2.0246
# |- Particle weight: 2.0246
#   |- Completion: How many blocks does the purple ship have?
#     |- Translation: (size Purple)
#     |- Score: 1.4394
#   |- Completion: How many squares does the blue ship cover?
#     |- Translation: (size Blue)
#     |- Score: 0.0000
#   |- Completion: How many total tiles are occupied by ships?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.0246
#
# Partial question: Is
# |- EIG mean: 0.2573
# |- EIG max: 0.7718
# |- Particle weight: 0.7718
#   |- Completion: Is there a ship at 1C?
#     |- Translation: (not (== (color 1-C) Water))
#     |- Score: 0.7718
#   |- Completion: Is the red ship on the same row as the purple ship?
#     |- Translation: (== (row (topleft (coloredTiles Red))) (row (topleft (coloredTiles Purple))))
#     |- Score: 0.0000
#   |- Completion: Is any of the ships touching the top or bottom of the grid?
#     |- Translation: (any (map (lambda x0 (or (== (topleft x0) (0-0)) (== (bottomright x0) (
#     |- Score: 0.0000
#
# Partial question: The
# |- EIG mean: 0.2149
# |- EIG max: 0.6447
# |- Particle weight: 0.6447
#   |- Completion: The first answer is 11.
#     |- Translation: (== (size Red) 11)
#     |- Score: 0.0000
#   |- Completion: The area is 2x4, and each ship must be an exact 3x1 or 1x3 rectangle.
#     |- Translation: (and (== (size Red) 3) (== (size Blue) 1) (== (size Purple) 1) (==
#     |- Score: 0.0000
#   |- Completion: The red ship has 4 tiles.
#     |- Translation: (== (size Red) 4)
#     |- Score: 0.6447
#
# Partial question: The red
# |- EIG mean: 0.2976
# |- EIG max: 0.8927
# |- Particle weight: 0.8927
#   |- Completion: The red ship is 7 squares long.
#     |- Translation: (== (size Red) 7)
#     |- Score: 0.0000
#   |- Completion: The red ship has 3 blocks
#     |- Translation: (== (size Red) 3)
#     |- Score: 0.8927
#   |- Completion: The red ship is 6 blocks long.
#     |- Translation: (== (size Red) 6)
#     |- Score: 0.0000
#
# Partial question: Is there
# |- EIG mean: 0.1648
# |- EIG max: 0.4943
# |- Particle weight: 0.4943
#   |- Completion: Is there a ship at 5I?
#     |- Translation: (not (== (color 5-I) Water))
#     |- Score: 0.0000
#   |- Completion: Is there a ship at 2E?
#     |- Translation: (not (== (color 2-E) Water))
#     |- Score: 0.4943
#   |- Completion: Is there a ship at 12C?
#     |- Translation: (not (== (color 12-C) Water))
#     |- Score: 0.0000
#
# Partial question: Is the
# |- EIG mean: 0.3304
# |- EIG max: 0.9913
# |- Particle weight: 0.9913
#   |- Completion: Is the blue ship touching any other ship?
#     |- Translation: (any (map (lambda x0 (touch Blue x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Is the red ship touching any other ships?
#     |- Translation: (any (map (lambda x0 (touch Red x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Is the red ship vertical?
#     |- Translation: (== (orient Red) V)
#     |- Score: 0.9913
#
# Partial question: How many
# |- EIG mean: 1.1547
# |- EIG max: 2.0246
# |- Particle weight: 2.0246
#   |- Completion: How many blocks is the blue ship?
#     |- Translation: (size Blue)
#     |- Score: 0.0000
#   |- Completion: How many coordinate pairs are there?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.0246
#   |- Completion: How many squares are occupied by the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4394
#
# Partial question: How many
# |- EIG mean: 0.6749
# |- EIG max: 2.0246
# |- Particle weight: 2.0246
#   |- Completion: How many ships are in total?
#     |- Translation: (++ (set AllColors))
#     |- Score: 0.0000
#   |- Completion: How many red ships are there?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) Red)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many squares are occupied by at least one ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.0246
#
# Partial question: Is there a
# |- EIG mean: 0.4726
# |- EIG max: 0.7370
# |- Particle weight: 0.7370
#   |- Completion: Is there a ship at 3C?
#     |- Translation: (not (== (color 3-C) Water))
#     |- Score: 0.0000
#   |- Completion: Is there a ship at 2F?
#     |- Translation: (not (== (color 2-F) Water))
#     |- Score: 0.6806
#   |- Completion: Is there a ship at 4F?
#     |- Translation: (not (== (color 4-F) Water))
#     |- Score: 0.7370
#
# Partial question: The red ship
# |- EIG mean: 0.8429
# |- EIG max: 0.9913
# |- Particle weight: 0.9913
#   |- Completion: The red ship is 4 blocks long.
#     |- Translation: (== (size Red) 4)
#     |- Score: 0.6447
#   |- Completion: The red ship is
#     |- Translation: (== (size Red) 3)
#     |- Score: 0.8927
#   |- Completion: The red ship is horizontal, and has 6 tiles.
#     |- Translation: (== (orient Red) H)
#     |- Score: 0.9913
#
# Partial question: Is the second
# |- EIG mean: 0.1558
# |- EIG max: 0.4675
# |- Particle weight: 0.4675
#   |- Completion: Is the second ship a red ship?
#     |- Translation: (== (coloredTiles 2) Red)
#     |- Score: 0.0000
#   |- Completion: Is the second ship the same shape as the first ship?
#     |- Translation: (== (shape 2) (shape 1))
#     |- Score: 0.0000
#   |- Completion: Is the second ship also purple?
#     |- Translation: (== (color 2-A) Purple)
#     |- Score: 0.4675
#
# Partial question: How many t
# |- EIG mean: 0.6749
# |- EIG max: 2.0246
# |- Particle weight: 2.0246
#   |- Completion: How many tiles does the biggest ship have?
#     |- Translation: (max (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many tiles do the ships have?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.0246
#   |- Completion: How many tiles are in each ship?
#     |- Translation: (map (lambda x0 (size x0)) (set AllColors))
#     |- Score: 0.0000
#
# Partial question: How many squares
# |- EIG mean: 0.4798
# |- EIG max: 1.4394
# |- Particle weight: 1.4394
#   |- Completion: How many squares are occupied by ships that are not horizontal?
#     |- Translation: (++ (map (lambda x0 (and (== (orient x0) V) (size x0))) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many squares are occupied by the largest ship?
#     |- Translation: (max (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many squares are occupied by the purple ship?
#     |- Translation: (size Purple)
#     |- Score: 1.4394
#
# Partial question: How many squares are
# |- EIG mean: 1.1547
# |- EIG max: 2.0246
# |- Particle weight: 2.0246
#   |- Completion: How many squares are occupied by the purple ship?
#     |- Translation: (size Purple)
#     |- Score: 1.4394
#   |- Completion: How many squares are occupied by at least one ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.0246
#   |- Completion: How many squares are occupied by the blue ship?
#     |- Translation: (size Blue)
#     |- Score: 0.0000
#
# Partial question: How many tiles
# |- EIG mean: 0.9596
# |- EIG max: 1.4394
# |- Particle weight: 1.4394
#   |- Completion: How many tiles are on the blue ship?
#     |- Translation: (size Blue)
#     |- Score: 0.0000
#   |- Completion: How many tiles are in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4394
#   |- Completion: How many tiles are in the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4394
#
# Partial question: The red ship has
# |- EIG mean: 0.2976
# |- EIG max: 0.8927
# |- Particle weight: 0.8927
#   |- Completion: The red ship has 3 blocks.
#     |- Translation: (== (size Red) 3)
#     |- Score: 0.8927
#   |- Completion: The red ship has 9 blocks, and the purple ship has 4 blocks.
#     |- Translation: (== (size Red) 9)
#     |- Score: 0.0000
#   |- Completion: The red ship has 5 tiles and is vertical.
#     |- Translation: (== (size Red) 5)
#     |- Score: 0.0000
#
# Partial question: Is the second square
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Is the second square to the right of the bottom left corner of the red ship green?
#     |- Translation: (== (color (+ (topleft (coloredTiles Red)) 2 0)) Green)
#     |- Score: 0.0000
#   |- Completion: Is the second square from the left-hand side occupied by a ship?
#     |- Translation: (== (color 2-L) Red)
#     |- Score: 0.0000
#   |- Completion: Is the second square of the red ship 4 units away from the first square of the red ship?
#     |- Translation: (== (distance 1-A 2-A) 4)
#     |- Score: 0.0000
#
# Partial question: Is there a ship
# |- EIG mean: 0.3896
# |- EIG max: 0.7599
# |- Particle weight: 0.7599
#   |- Completion: Is there a ship at 6F?
#     |- Translation: (== (color 6-F) Water)
#     |- Score: 0.4088
#   |- Completion: Is there a ship on any of the tiles at 3E, 2D, 4E, 1C, 2C, 3C, or
#     |- Translation: (any (map (lambda x0 (== (coloredTiles x0) (list 3-E 2-D 4-E
#     |- Score: 0.0000
#   |- Completion: Is there a ship at 1B?
#     |- Translation: (not (== (color 1-B) Water))
#     |- Score: 0.7599
#
# Partial question: The red ship has
# |- EIG mean: 0.6302
# |- EIG max: 0.9980
# |- Particle weight: 0.9980
#   |- Completion: The red ship has 3 tiles.
#     |- Translation: (== (size Red) 3)
#     |- Score: 0.8927
#   |- Completion: The red ship has 5 blocks.
#     |- Translation: (== (size Red) 5)
#     |- Score: 0.0000
#   |- Completion: The red ship has 2 blocks.
#     |- Translation: (== (size Red) 2)
#     |- Score: 0.9980
#
# Partial question: Is there a ship at
# |- EIG mean: 0.4591
# |- EIG max: 0.7606
# |- Particle weight: 0.7606
#   |- Completion: Is there a ship at 9C?
#     |- Translation: (not (== (color 9-C) Water))
#     |- Score: 0.0000
#   |- Completion: Is there a ship at 1F?
#     |- Translation: (not (== (color 1-F) Water))
#     |- Score: 0.6169
#   |- Completion: Is there a ship at 3A?
#     |- Translation: (not (== (color 3-A) Water))
#     |- Score: 0.7606
#
# Partial question: How many tiles does
# |- EIG mean: 0.4798
# |- EIG max: 1.4394
# |- Particle weight: 1.4394
#   |- Completion: How many tiles does the ship at 1C occupy?
#     |- Translation: (size (coloredTiles (color 1-C)))
#     |- Score: 0.0000
#   |- Completion: How many tiles does the red ship have?
#     |- Translation: (size Red)
#     |- Score: 1.4394
#   |- Completion: How many tiles does the blue ship have?
#     |- Translation: (size Blue)
#     |- Score: 0.0000
#
# Partial question: How many squares are occupied
# |- EIG mean: 1.1547
# |- EIG max: 2.0246
# |- Particle weight: 2.0246
#   |- Completion: How many squares are occupied by the red ship?
#     |- Translation: (size Red)
#     |- Score: 1.4394
#   |- Completion: How many squares are occupied by both ships?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 2.0246
# ...
#
# Partial question: What is the
# |- EIG mean: 0.3181
# |- EIG max: 0.9544
# |- Particle weight: 0.9544
#   |- Completion: What is the leftmost square occupied by a ship?
#     |- Translation: (min (map (lambda x0 (topleft (coloredTiles x0))) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: What is the coordinate of the rightmost square occupied by the red ship?
#     |- Translation: (bottomright (coloredTiles Red))
#     |- Score: -0.0000
#   |- Completion: What is the coordinate of the leftmost square occupied by the purple ship?
#     |- Translation: (topleft (coloredTiles Purple))
#     |- Score: 0.9544
#
# Partial question: Are any of
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Are any of the ships touching each other?
#     |- Translation: (any (map (lambda x0 (touch x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are any of the ships overlapping?
#     |- Translation: (any (map (lambda x0 (overlap x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are any of the ships touching?
#     |- Translation: (any (map (lambda x0 (touch x0)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: How many total
# |- EIG mean: 0.5204
# |- EIG max: 1.5613
# |- Particle weight: 1.5613
#   |- Completion: How many total squares are occupied by either red or blue ships?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set (union Red Blue))))
#     |- Score: 0.0000
#   |- Completion: How many total squares are occupied by one ship?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 1.5613
#   |- Completion: How many total squares are occupied by battleships?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) Water)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Is the pur
# |- EIG mean: 0.2704
# |- EIG max: 0.8113
# |- Particle weight: 0.8113
#   |- Completion: Is the purple ship farthest north?
#     |- Translation: (== (topleft (coloredTiles Purple)) (min (map (lambda x0 (topleft (coloredTiles x0)))
#     |- Score: 0.0000
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.8113
#   |- Completion: Is the purple ship at 1F?
#     |- Translation: (== (topleft (coloredTiles Purple)) 1-F)
#     |- Score: -0.0000
#
# Partial question: Three-letter
# |- EIG mean: 0.0000
# |- EIG max: -0.0000
# |- Particle weight: 0.0000
#   |- Completion: Three-letter code for the ship colors:
#     |- Translation: (map (lambda x0 (string-append (string-upcase (string-take (color x0) 1)) (string-drop (
#     |- Score: 0.0000
#   |- Completion: Three-letter words:
#     |- Translation: (map (lambda x0 (length x0)) (set AllColors))
#     |- Score: 0.0000
#   |- Completion: Three-letter answer to the question:
#     |- Translation: (size Red)
#     |- Score: -0.0000
#
# Partial question: Are any of the
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Are any of the ships touching?
#     |- Translation: (any (map (lambda x0 (touch x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are any of the ships overlapping?
#     |- Translation: (any (map (lambda x0 (overlap x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are any of the ships touching?
#     |- Translation: (any (map touch (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Three-letter model
# |- EIG mean: 0.0000
# |- EIG max: -0.0000
# |- Particle weight: 0.0000
#   |- Completion: Three-letter model:
#     |- Translation: (model 3)
#     |- Score: 0.0000
#   |- Completion: Three-letter model of the grid:
#     |- Translation: (map (lambda x0 (map (lambda x1 (color x1)) (map (lambda x2 (map (lambda x3 (color x
#     |- Score: 0.0000
#   |- Completion: Three-letter modeling question:
#     |- Translation: (== (size Red) 3)
#     |- Score: -0.0000
#
# Partial question: What is the distance
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: What is the distance between 1F and 3B?
#     |- Translation: (distance 1-F 3-B)
#     |- Score: 0.0000
#   |- Completion: What is the distance between the leftmost and rightmost squares occupied by the red ship?
#     |- Translation: (distance (topleft (coloredTiles Red)) (bottomright (coloredTiles Red)))
#     |- Score: 0.0000
#   |- Completion: What is the distance between the ships?
#     |- Translation: (distance (topleft (coloredTiles Red)) (topleft (coloredTiles Purple)))
#     |- Score: 0.0000
#
# Partial question: Is the purple
# |- EIG mean: 0.0000
# |- EIG max: -0.0000
# |- Particle weight: 0.0000
#   |- Completion: Is the purple ship touching any of the ships?
#     |- Translation: (any (map (lambda x0 (touch Purple x0)) (set AllColors)))
#     |- Score: -0.0000
#   |- Completion: Is the purple ship above or below the red ship?
#     |- Translation: (or (and (== (orient Purple) V) (< (topleft (coloredTiles Purple)) (topleft (colored
#     |- Score: 0.0000
#   |- Completion: Is the purple ship touching the red ship?
#     |- Translation: (touch Purple Red)
#     |- Score: -0.0000
#
# Partial question: How many total squares
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many total squares are free?
#     |- Translation: (++ (map (lambda x0 (== (color x0) Water)) (set AllCoords)))
#     |- Score: 0.0000
#   |- Completion: How many total squares are occupied by ships and 2x2 tiles?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)) (map (lambda x0 (size x0)) (set
#     |- Score: 0.0000
#   |- Completion: How many total squares are occupied by ships in the blue area?
#     |- Translation: (++ (map (lambda x0 (size x0)) (filter (lambda x1 (== (color x1) Blue)) (set AllCol
#     |- Score: 0.0000
#
# Partial question: Three-letter model solution
# |- EIG mean: 0.0000
# |- EIG max: -0.0000
# |- Particle weight: 0.0000
#   |- Completion: Three-letter model solution.
#     |- Translation: (size Red)
#     |- Score: -0.0000
#   |- Completion: Three-letter model solution
#     |- Translation: (size Red)
#     |- Score: -0.0000
#   |- Completion: Three-letter model solution:
#     |- Translation: (size Red)
#     |- Score: -0.0000
#
# Partial question: Is the purple ship
# |- EIG mean: 0.5409
# |- EIG max: 0.8113
# |- Particle weight: 0.8113
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.8113
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.8113
#   |- Completion: Is the purple ship the longest?
#     |- Translation: (== (size Purple) (max (map (lambda x0 (size x0)) (set AllColors))))
#     |- Score: 0.0000
#
# Partial question: Are any of the ships
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Are any of the ships touching?
#     |- Translation: (any (map (lambda x0 (touch x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are any of the ships touching the edge of the map?
#     |- Translation: (any (map (lambda x0 (or (== (topleft x0) (topleft Map)) (== (bottomright x0) (
#     |- Score: 0.0000
#   |- Completion: Are any of the ships touching each other?
#     |- Translation: (any (map (lambda x0 (touch x0)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: How many total squares are
# |- EIG mean: 0.5204
# |- EIG max: 1.5613
# |- Particle weight: 1.5613
#   |- Completion: How many total squares are occupied by ships AND water?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)) (map (lambda x0 (size x0)) (set
#     |- Score: 0.0000
#   |- Completion: How many total squares are free?
#     |- Translation: (++ (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 1.5613
#   |- Completion: How many total squares are NOT occupied by ships?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) ())) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: What is the distance between
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: What is the distance between the leftmost and rightmost square occupied by the red ship?
#     |- Translation: (distance (topleft (coloredTiles Red)) (bottomright (coloredTiles Red)))
#     |- Score: 0.0000
#   |- Completion: What is the distance between the ships?
#     |- Translation: (distance (topleft (coloredTiles Red)) (topleft (coloredTiles Purple)))
#     |- Score: 0.0000
#   |- Completion: What is the distance between 4F and the leftmost square occupied by a ship?
#     |- Translation: (distance 4-F (bottomleft (coloredTiles (first (filter (lambda x0 (== (orient x0) H)) (
#     |- Score: 0.0000
#
# Partial question: How many total squares are not
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many total squares are not occupied by ships?
#     |- Translation: (-- (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many total squares are not occupied by ships?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) Water)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many total squares are not occupied by ships?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) ())) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Is the purple ship touch
# |- EIG mean: 0.2704
# |- EIG max: 0.8113
# |- Particle weight: 0.8113
#   |- Completion: Is the purple ship touching the red ship?
#     |- Translation: (touch Purple Red)
#     |- Score: -0.0000
#   |- Completion: Is the purple ship touching any other ships?
#     |- Translation: (any (map (lambda x0 (touch Purple x0)) (set AllColors)))
#     |- Score: -0.0000
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.8113
#
# Partial question: Three-letter model solution:
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Three-letter model solution:
#     |- Translation: (size Red)
#     |- Score: -0.0000
#   |- Completion: Three-letter model solution:
#     |- Translation: (size Red)
#     |- Score: -0.0000
#   |- Completion: Three-letter model solution:
#     |- Translation: (lambda (x0) (lambda (x1) (lambda (x2) (lambda (x3) (lambda (x4) (lambda
#     |- Score: 0.0000
#
# Partial question: Are any of the ships touch
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Are any of the ships touching the edge of the map?
#     |- Translation: (any (map (lambda x0 (or (== (topleft x0) (topleft Map)) (== (bottomright x0) (
#     |- Score: 0.0000
#   |- Completion: Are any of the ships touching each other?
#     |- Translation: (any (map (lambda x0 (touch x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are any of the ships touching the edge of the board?
#     |- Translation: (any (map (lambda x0 (or (== (topleft x0) (0-0)) (== (bottomright x0) (
#     |- Score: 0.0000
#
# Partial question: What is the distance between the
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: What is the distance between the front edge of the red ship and the left edge of the puzzle?
#     |- Translation: (distance (topleft (coloredTiles Red)) (topleft Puzzle))
#     |- Score: 0.0000
#   |- Completion: What is the distance between the rightmost and leftmost squares occupied by the red ship?
#     |- Translation: (distance (bottomright (coloredTiles Red)) (topleft (coloredTiles Red)))
#     |- Score: 0.0000
#   |- Completion: What is the distance between the middle of the ocean and the first tile of the red ship?
#     |- Translation: (distance (middle Ocean) (topleft (coloredTiles Red)))
#     |- Score: 0.0000
#
# Partial question: How many total squares are not occupied
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many total squares are not occupied by ships?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) Water)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many total squares are not occupied by ships?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) Water)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many total squares are not occupied by ships?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) ())) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Is the purple ship touching
# |- EIG mean: 0.5409
# |- EIG max: 0.8113
# |- Particle weight: 0.8113
#   |- Completion: Is the purple ship touching the green ship?
#     |- Translation: (touch Purple Green)
#     |- Score: 0.0000
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.8113
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.8113
#
# Partial question: Three-letter model solution: SH
# |- EIG mean: 0.0000
# |- EIG max: -0.0000
# |- Particle weight: 0.0000
#   |- Completion: Three-letter model solution: SHIP
#     |- Translation: (== (size Red) 3)
#     |- Score: -0.0000
#   |- Completion: Three-letter model solution: SHIP
#     |- Translation: (== (size Red) 3)
#     |- Score: -0.0000
#   |- Completion: Three-letter model solution: SHTP
#     |- Translation: (== (size Red) 3)
#     |- Score: -0.0000
#
# Partial question: Are any of the ships touching
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: Are any of the ships touching?
#     |- Translation: (any (map (lambda x0 (touch x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are any of the ships touching the diagram?
#     |- Translation: (any (map (lambda x0 (touch x0 Diagram)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: Are any of the ships touching the edge?
#     |- Translation: (any (map (lambda x0 (or (== (topleft x0) (0-0)) (== (bottomright x0) (
#     |- Score: 0.0000
#
# Partial question: What is the distance between the first
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: What is the distance between the first block of the blue ship and the rightmost block of the red ship?
#     |- Translation: (distance (topleft (coloredTiles Blue)) (bottomright (coloredTiles Red)))
#     |- Score: 0.0000
#   |- Completion: What is the distance between the first block of the red ship and the first block of the blue ship?
#     |- Translation: (distance (topleft (coloredTiles Red)) (topleft (coloredTiles Blue)))
#     |- Score: 0.0000
#   |- Completion: What is the distance between the first and last block of the purple ship?
#     |- Translation: (distance (topleft (coloredTiles Purple)) (bottomright (coloredTiles Purple)))
#     |- Score: 0.0000
#
# Partial question: How many total squares are not occupied by
# |- EIG mean: 0.0000
# |- EIG max: 0.0000
# |- Particle weight: 0.0000
#   |- Completion: How many total squares are not occupied by ships?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) Water)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many total squares are not occupied by ships?
#     |- Translation: (-- (map (lambda x0 (size x0)) (set AllColors)))
#     |- Score: 0.0000
#   |- Completion: How many total squares are not occupied by ships?
#     |- Translation: (++ (map (lambda x0 (== (coloredTiles x0) Water)) (set AllColors)))
#     |- Score: 0.0000
#
# Partial question: Is the purple ship touching the
# |- EIG mean: 0.8113
# |- EIG max: 0.8113
# |- Particle weight: 0.8113
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.8113
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.8113
#   |- Completion: Is the purple ship touching the blue ship?
#     |- Translation: (touch Purple Blue)
#     |- Score: 0.8113
#
# Partial question: Three-letter model solution: SHV
# |- EIG mean: 0.0000
# |- EIG max: -0.0000
# |- Particle weight: 0.0000
#   |- Completion: Three-letter model solution: SHV
#     |- Translation: (== (size Red) 3)
#     |- Score: -0.0000
#   |- Completion: Three-letter model solution: SHVTLB
#     |- Translation: (== (size Red) 3)
#     |- Score: -0.0000
#   |- Completion: Three-letter model solution: SHV
#     |- Translation: (== (size Red) 3)
#     |- Score: -0.0000

# %%
df_results
# Out:
#                                              prefix  \
# 0   Is the large blue ship horizontal and vertical?
# 1                                                Is
# 2                                                Is
# 3                                                Is
# 4                                            Is the
# 5                                            Is the
# 6                                            Is the
# 7                                      Is the large
# 8                                      Is the large
# 9                                      Is the large
# 10                                Is the large blue
# 11                                Is the large blue
# 12                                Is the large blue
# 13                           Is the large blue ship
# 14                           Is the large blue ship
# 15                           Is the large blue ship
# 16                Is the large blue ship horizontal
# 17                Is the large blue ship horizontal
# 18                Is the large blue ship horizontal
# 19            Is the large blue ship horizontal and
# 20            Is the large blue ship horizontal and
# 21            Is the large blue ship horizontal and
# 22   Is the large blue ship horizontal and vertical
# 23   Is the large blue ship horizontal and vertical
# 24   Is the large blue ship horizontal and vertical
# 25  Is the large blue ship horizontal and vertical?
# 26  Is the large blue ship horizontal and vertical?
# 27  Is the large blue ship horizontal and vertical?
#
#                                            completion  \
# 0     Is the large blue ship horizontal and vertical?
# 1           Is the purple ship next to the blue ship?
# 2                     Is there a ship in the top row?
# 3            Is the blue ship on the leftmost column?
# 4   Is the purple ship at least as long as the blu...
# 5             Is the purple ship above the blue ship?
# 6                        Is the blue ship horizontal?
# 7                       Is the large ship horizontal?
# 8                       Is the large ship horizontal?
# 9   Is the large ship at 1A to the left of the sma...
# 10                 Is the large blue ship horizontal?
# 11                 Is the large blue ship horizontal?
# 12                   Is the large blue ship vertical?
# 13            Is the large blue ship at the top left?
# 14  Is the large blue ship touching the small blue...
# 15  Is the large blue ship touching the large red ...
# 16     Is the large blue ship horizontal or vertical?
# 17                 Is the large blue ship horizontal?
# 18                 Is the large blue ship horizontal?
# 19  Is the large blue ship horizontal and the smal...
# 20    Is the large blue ship horizontal and vertical?
# 21  Is the large blue ship horizontal and touching...
# 22    Is the large blue ship horizontal and vertical?
# 23    Is the large blue ship horizontal and vertical?
# 24    Is the large blue ship horizontal and vertical?
# 25    Is the large blue ship horizontal and vertical?
# 26    Is the large blue ship horizontal and vertical?
# 27    Is the large blue ship horizontal and vertical?
#
#                                           translation     score     type  \
# 0   (and (== (orient LargeBlue) H) (== (orient Lar...  0.000000    final
# 1                                 (touch Purple Blue)  0.756291  rollout
# 2   (any (map (lambda x0 (== (top x0) 1)) (set All...  0.000000  rollout
# 3            (== (topleft (coloredTiles Blue)) (0-0))  0.000000  rollout
# 4                      (>= (size Purple) (size Blue))  0.000000  rollout
# 5                                 (above Purple Blue)  0.000000  rollout
# 6                                (== (orient Blue) H)  0.993542  rollout
# 7                               (== (orient Large) H)  0.000000  rollout
# 8                               (== (orient Large) H)  0.000000  rollout
# 9    (left (coloredTiles Large) (coloredTiles Small))  0.000000  rollout
# 10                          (== (orient LargeBlue) H)  0.000000  rollout
# 11                          (== (orient LargeBlue) H)  0.000000  rollout
# 12                          (== (orient LargeBlue) V)  0.000000  rollout
# 13  (== (topleft (coloredTiles Blue)) (topleft (co...  0.000000  rollout
# 14                                 (touch Large Blue)  0.000000  rollout
# 15                       (touch Large Blue Large Red)  0.000000  rollout
# 16                                 (orient LargeBlue)  0.000000  rollout
# 17                          (== (orient LargeBlue) H)  0.000000  rollout
# 18                          (== (orient LargeBlue) H)  0.000000  rollout
# 19  (and (== (orient LargeBlue) H) (== (orient Red...  0.000000  rollout
# 20  (and (== (orient LargeBlue) H) (== (orient Lar...  0.000000  rollout
# 21  (and (== (orient LargeBlue) H) (touch LargeBlu...  0.000000  rollout
# 22  (and (== (orient LargeBlue) H) (== (orient Lar...  0.000000  rollout
# 23  (and (== (orient LargeBlue) H) (== (orient Lar...  0.000000  rollout
# 24  (and (== (orient LargeBlue) H) (== (orient Lar...  0.000000  rollout
# 25  (and (== (orient LargeBlue) H) (== (orient Lar...  0.000000  rollout
# 26  (and (== (orient LargeBlue) H) (== (orient Lar...  0.000000  rollout
# 27  (and (== (orient LargeBlue) H) (== (orient Lar...  0.000000  rollout
#
#     particle model_type  trial_id
# 0          0   COMBINED         1
# 1          0   COMBINED         1
# 2          0   COMBINED         1
# 3          0   COMBINED         1
# 4          0   COMBINED         1
# 5          0   COMBINED         1
# 6          0   COMBINED         1
# 7          0   COMBINED         1
# 8          0   COMBINED         1
# 9          0   COMBINED         1
# 10         0   COMBINED         1
# 11         0   COMBINED         1
# 12         0   COMBINED         1
# 13         0   COMBINED         1
# 14         0   COMBINED         1
# 15         0   COMBINED         1
# 16         0   COMBINED         1
# 17         0   COMBINED         1
# 18         0   COMBINED         1
# 19         0   COMBINED         1
# 20         0   COMBINED         1
# 21         0   COMBINED         1
# 22         0   COMBINED         1
# 23         0   COMBINED         1
# 24         0   COMBINED         1
# 25         0   COMBINED         1
# 26         0   COMBINED         1
# 27         0   COMBINED         1
